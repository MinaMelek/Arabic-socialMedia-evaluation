# %% [markdown]
# # Install requirements

# %%
# !pip install -r requirements.txt

# %% [markdown]
# # Import libraries

# %%
from Evaluation_function import Evaluate
import pandas as pd
from gensim.models import KeyedVectors, Word2Vec
from utilities import WordVecVectorizer, EpochSaver

pd.options.mode.chained_assignment = None
pd.set_option('display.max_colwidth', 100)
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # Evaluation Using Word2vec vectorization

# %%
df = pd.read_csv('./data/data.csv')
print(df.shape)
eval = Evaluate(df)
transformed = eval.transform(vectorizer="w2v", vect_path='./models/w2v_model.bin')
predictiones = eval.predict(input=transformed, model_name='FCNN_w2v_model')
eval.add_dicts()
eval.visualize(kind='pie')
eval.visualize(kind='bar')
Final_data = eval.get_data()
print(Final_data.shape)
Final_data.sample(5, random_state=10)
# Out:
# (3831, 5)
# Loading Word2Vec model ...
# Transforming data ... Done.
# Loading Classification model ...
# Evaluating the model ... Done.
# Adding dictionaries ...  Done.
# Visualizing ...
# Visualizing ...
# (3831, 6)
#                   message predicted  ...        ALL_Categories              cleaned
# 1462  المواعيد وسعر الكشف       obj  ...       Mixed-Inquiries  المواعيد وسعر الكشف
# 2783     فيه فرع بني سويف       obj  ...       Mixed-Inquiries     فيه فرع بني سويف
# 3231    الكشف لكام ةالحشو       obj  ...         Price-Inquiry    الكشف لكام ةالحشو
# 1198             جرين بيل       obj  ...  General Conversation             جرين بيل
# 372            بكم الجلسه       obj  ...         Price-Inquiry           بكم الجلسه
#
# [5 rows x 6 columns]

# %%
# Loading the w2v model externally, instead of loading it everytime the function is called
#########################################################
print("Loading word2vec (Externally) ..", end=' ')
word2vec = KeyedVectors.load_word2vec_format('./models/w2v_model.bin', binary=True)
vect_model = WordVecVectorizer(word2vec)
print("Done.")
#########################################################
# eval.transform takes vect_model instead of vect_path
transformed_2 = eval.transform(vectorizer="w2v", vect_model=vect_model)

# %% [markdown]
# # Evaluation using a majority voting between 3 different models

# %%
from time import time

df = pd.read_csv('./data/data.csv')
t = []
t.append(time()) # Start time
# Initialization
eval = Evaluate(df, text_column='message')
t.append(time()) # init time
# Tfidf-based prediction
transformed = eval.transform(vectorizer="tfidf", vect_path='./models/tfidf_features.pkl')
predictiones = eval.predict(input=transformed, model_name='FCNN_tfidf_model')
t.append(time()) # tfidf time
# Word2vec-based prediction
transformed_2 = eval.transform(vectorizer="w2v", vect_path='./models/w2v_model.bin')
predictiones_2 = eval.predict(input=transformed_2, model_name='FCNN_w2v_model')
t.append(time()) # w2v time
# Lexicons-based prediction
predictiones_3 = eval.predict(lexicon_prediction=True, lex_path='models/Full_lexicons.csv')
t.append(time()) # lex computing time
# Objective categorization
eval.add_dicts()
t.append(time()) # dictionary computing time
# Visualization
eval.visualize(kind='pie')
eval.visualize(kind='bar')
t.append(time()) # Visualization time / End time

Final_data = eval.get_data()
Final_data.sample(5, random_state=10)
# Out:
# Loading Tf-Idf model ...
# Transforming data ... Done.
# Loading Classification model ...
# Evaluating the model ... Done.
# Loading Word2Vec model ...
# Transforming data ... Done.
# Loading Classification model ...
# Evaluating the model ... Done.
# Loading Lexicons ...
# Done.
# Adding dictionaries ...  Done.
# Visualizing ...
# Visualizing ...
#                   message predicted  ...        ALL_Categories              cleaned
# 1462  المواعيد وسعر الكشف       obj  ...       Mixed-Inquiries  المواعيد وسعر الكشف
# 2783     فيه فرع بني سويف       obj  ...       Mixed-Inquiries     فيه فرع بني سويف
# 3231    الكشف لكام ةالحشو       obj  ...         Price-Inquiry    الكشف لكام ةالحشو
# 1198             جرين بيل       obj  ...  General Conversation             جرين بيل
# 372            بكم الجلسه       obj  ...         Price-Inquiry           بكم الجلسه
#
# [5 rows x 6 columns]

# %% [markdown]
# ## Time analysis

# %%
print("Time analysis:")
print("Full time taken: {:.2f} s".format(t[-1]-t[0]))
print("init time: {:.2f} s".format(t[1]-t[0]))
print("tfidf time: {:.2f} s".format(t[2]-t[1]))
print("w2v time: {:.2f} s".format(t[3]-t[2]))
print("lex computing time: {:.2f} s".format(t[4]-t[3]))
print("dictionary computing time: {:.2f} s".format(t[5]-t[4]))
print("Visualization time: {:.2f} s".format(t[6]-t[5]))
# Out:
# Time analysis:
# Full time taken: 13.15 s
# init time: 0.60 s
# tfidf time: 2.67 s
# w2v time: 3.31 s
# lex computing time: 0.99 s
# dictionary computing time: 4.55 s
# Visualization time: 1.03 s
